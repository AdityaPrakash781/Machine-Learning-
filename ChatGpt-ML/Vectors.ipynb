# %%
import numpy as np
house = np.array([1200,3,10,8])
print("House Vector :",house)
print("House Vector Dimensions:",house.shape)
# Out:
# House Vector : [1200    3   10    8]
# House Vector Dimensions: (4,)

# %%
cars = np.array([500,4,2])
student = np.array([175,5,2005])
smartphone = np.array([30,15])

# %%
a = np.array([3,5])
b = np.array([2,4])
c = a + b
print(c)
print(c*2)
# Out:
# [5 9]
# [10 18]
